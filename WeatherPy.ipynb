# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 598

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}&units=metric"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"] 
        city_humidity = city_weather["main"]["humidity"] 
        city_clouds = city_weather["clouds"]["all"] 
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | cam pha mines
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | margaret river
# Processing Record 5 of Set 1 | kavaratti
# Processing Record 6 of Set 1 | chahuites
# Processing Record 7 of Set 1 | lincoln
# Processing Record 8 of Set 1 | waitangi
# Processing Record 9 of Set 1 | newman
# Processing Record 10 of Set 1 | kagizman
# Processing Record 11 of Set 1 | port-aux-francais
# Processing Record 12 of Set 1 | cabo san lucas
# Processing Record 13 of Set 1 | butajira
# Processing Record 14 of Set 1 | ta`u
# Processing Record 15 of Set 1 | kingston
# Processing Record 16 of Set 1 | oriximina
# Processing Record 17 of Set 1 | khandyga
# Processing Record 18 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 19 of Set 1 | blackmans bay
# Processing Record 20 of Set 1 | tofol
# Processing Record 21 of Set 1 | magadan
# Processing Record 22 of Set 1 | ishigaki
# Processing Record 23 of Set 1 | st. john's
# Processing Record 24 of Set 1 | invercargill
# Processing Record 25 of Set 1 | reggane
# Processing Record 26 of Set 1 | kargopol'
# Processing Record 27 of Set 1 | baoro
# Processing Record 28 of Set 1 | chervona sloboda
# Processing Record 29 of Set 1 | dauphin
# Processing Record 30 of Set 1 | georgetown
# Processing Record 31 of Set 1 | puerto natales
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | kodiak
# Processing Record 34 of Set 1 | klyuchi
# Processing Record 35 of Set 1 | grytviken
# Processing Record 36 of Set 1 | tromso
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | wailua homesteads
# Processing Record 40 of Set 1 | hawaiian paradise park
# Processing Record 41 of Set 1 | la grande
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | belyy yar
# Processing Record 44 of Set 1 | kapuskasing
# Processing Record 45 of Set 1 | havelberg
# Processing Record 46 of Set 1 | collie
# Processing Record 47 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 48 of Set 1 | cidreira
# Processing Record 49 of Set 1 | gadzhiyevo
# Processing Record 50 of Set 1 | paracatu
# Processing Record 0 of Set 2 | port blair
# Processing Record 1 of Set 2 | biasca
# Processing Record 2 of Set 2 | shiprock
# Processing Record 3 of Set 2 | bollnas
# Processing Record 4 of Set 2 | talnakh
# Processing Record 5 of Set 2 | isafjordur
# Processing Record 6 of Set 2 | laguna
# Processing Record 7 of Set 2 | teguise
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | lodeynoye pole
# Processing Record 10 of Set 2 | al jawf
# Processing Record 11 of Set 2 | mabaruma
# Processing Record 12 of Set 2 | del rio
# Processing Record 13 of Set 2 | ancud
# Processing Record 14 of Set 2 | douz
# Processing Record 15 of Set 2 | kamennogorsk
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | imam qasim
# Processing Record 18 of Set 2 | anadyr
# Processing Record 19 of Set 2 | tabalah
# Processing Record 20 of Set 2 | espargos
# City not found. Skipping...
# Processing Record 21 of Set 2 | nar'yan-mar
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | codrington
# Processing Record 24 of Set 2 | soto la marina
# Processing Record 25 of Set 2 | nemuro
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | fisterra
# Processing Record 28 of Set 2 | san luis de la loma
# Processing Record 29 of Set 2 | fond parisien
# Processing Record 30 of Set 2 | vilyuchinsk
# Processing Record 31 of Set 2 | laikit, laikit ii (dimembe)
# Processing Record 32 of Set 2 | lihue
# Processing Record 33 of Set 2 | minas de marcona
# Processing Record 34 of Set 2 | edinburgh of the seven seas
# Processing Record 35 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 36 of Set 2 | tchintabaraden
# Processing Record 37 of Set 2 | tarnogskiy gorodok
# Processing Record 38 of Set 2 | atafu village
# Processing Record 39 of Set 2 | nouadhibou
# Processing Record 40 of Set 2 | matipo
# Processing Record 41 of Set 2 | ribeira grande
# Processing Record 42 of Set 2 | howard springs
# Processing Record 43 of Set 2 | camarinas
# Processing Record 44 of Set 2 | kamloops
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | nogliki
# Processing Record 47 of Set 2 | ushuaia
# Processing Record 48 of Set 2 | enewetak
# Processing Record 49 of Set 2 | saurimo
# Processing Record 0 of Set 3 | san ignacio de velasco
# Processing Record 1 of Set 3 | iqaluit
# Processing Record 2 of Set 3 | ilulissat
# Processing Record 3 of Set 3 | port augusta
# Processing Record 4 of Set 3 | recani
# Processing Record 5 of Set 3 | rundu
# Processing Record 6 of Set 3 | arraial do cabo
# Processing Record 7 of Set 3 | colonia
# Processing Record 8 of Set 3 | zinapecuaro
# Processing Record 9 of Set 3 | tiksi
# Processing Record 10 of Set 3 | malango
# Processing Record 11 of Set 3 | bilibino
# Processing Record 12 of Set 3 | ambon
# Processing Record 13 of Set 3 | stanley
# Processing Record 14 of Set 3 | egilsstadir
# Processing Record 15 of Set 3 | tobelo
# Processing Record 16 of Set 3 | basse-terre
# Processing Record 17 of Set 3 | kolonia
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | coyhaique
# Processing Record 20 of Set 3 | cadale
# Processing Record 21 of Set 3 | ahau
# City not found. Skipping...
# Processing Record 22 of Set 3 | griffith
# Processing Record 23 of Set 3 | cassilandia
# Processing Record 24 of Set 3 | gulsehir
# Processing Record 25 of Set 3 | touros
# Processing Record 26 of Set 3 | fort bragg
# Processing Record 27 of Set 3 | dawson creek
# Processing Record 28 of Set 3 | saipan
# Processing Record 29 of Set 3 | chonchi
# Processing Record 30 of Set 3 | haiku-pauwela
# Processing Record 31 of Set 3 | labytnangi
# Processing Record 32 of Set 3 | la gi
# Processing Record 33 of Set 3 | saint cloud
# Processing Record 34 of Set 3 | vadso
# Processing Record 35 of Set 3 | kayankulam
# Processing Record 36 of Set 3 | fyodorovka
# Processing Record 37 of Set 3 | carbonear
# Processing Record 38 of Set 3 | i-n-salah
# Processing Record 39 of Set 3 | puerto armuelles
# Processing Record 40 of Set 3 | senanga
# Processing Record 41 of Set 3 | tolanaro
# Processing Record 42 of Set 3 | kuvshinovo
# Processing Record 43 of Set 3 | saint-philippe
# Processing Record 44 of Set 3 | xiahu
# Processing Record 45 of Set 3 | terrace
# Processing Record 46 of Set 3 | dien bien phu
# City not found. Skipping...
# Processing Record 47 of Set 3 | susuman
# Processing Record 48 of Set 3 | port saint john's
# Processing Record 49 of Set 3 | katsuura
# Processing Record 0 of Set 4 | santa marta
# Processing Record 1 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 2 of Set 4 | kapa'a
# Processing Record 3 of Set 4 | alo
# Processing Record 4 of Set 4 | rio grande
# City not found. Skipping...
# Processing Record 5 of Set 4 | sisimiut
# Processing Record 6 of Set 4 | yerofey pavlovich
# Processing Record 7 of Set 4 | qaqortoq
# Processing Record 8 of Set 4 | socorro
# Processing Record 9 of Set 4 | kogota
# Processing Record 10 of Set 4 | ca mau
# Processing Record 11 of Set 4 | port glaud
# City not found. Skipping...
# Processing Record 12 of Set 4 | yuzhno-kurilsk
# Processing Record 13 of Set 4 | utrik
# Processing Record 14 of Set 4 | sierra grande
# Processing Record 15 of Set 4 | copiapo
# Processing Record 16 of Set 4 | avarua
# Processing Record 17 of Set 4 | olonkinbyen
# Processing Record 18 of Set 4 | brisas de zicatela
# Processing Record 19 of Set 4 | keflavik
# Processing Record 20 of Set 4 | cogealac
# Processing Record 21 of Set 4 | geraldton
# Processing Record 22 of Set 4 | santa rosa de rio primero
# Processing Record 23 of Set 4 | tashtyp
# Processing Record 24 of Set 4 | ola
# Processing Record 25 of Set 4 | gaspe
# Processing Record 26 of Set 4 | selibaby
# Processing Record 27 of Set 4 | sitka
# Processing Record 28 of Set 4 | sinabang
# Processing Record 29 of Set 4 | san juan
# Processing Record 30 of Set 4 | alofi
# Processing Record 31 of Set 4 | antsiranana
# Processing Record 32 of Set 4 | hovd
# Processing Record 33 of Set 4 | nadym
# Processing Record 34 of Set 4 | yutan
# Processing Record 35 of Set 4 | vila franca do campo
# Processing Record 36 of Set 4 | taulaga
# Processing Record 37 of Set 4 | tura
# Processing Record 38 of Set 4 | kidal
# Processing Record 39 of Set 4 | el higo
# Processing Record 40 of Set 4 | namtsy
# Processing Record 41 of Set 4 | badger
# Processing Record 42 of Set 4 | sindangan
# Processing Record 43 of Set 4 | papatowai
# Processing Record 44 of Set 4 | nong khae
# Processing Record 45 of Set 4 | al wajh
# Processing Record 46 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 47 of Set 4 | sonsorol village
# City not found. Skipping...
# Processing Record 48 of Set 4 | pakuranga
# Processing Record 49 of Set 4 | pago pago
# Processing Record 0 of Set 5 | papao
# Processing Record 1 of Set 5 | kone
# Processing Record 2 of Set 5 | iskateley
# Processing Record 3 of Set 5 | acarau
# Processing Record 4 of Set 5 | kununurra
# Processing Record 5 of Set 5 | mount gambier
# Processing Record 6 of Set 5 | shimoda
# Processing Record 7 of Set 5 | qurayyat
# Processing Record 8 of Set 5 | mtambile
# Processing Record 9 of Set 5 | mingshui
# Processing Record 10 of Set 5 | opochka
# Processing Record 11 of Set 5 | kutum
# Processing Record 12 of Set 5 | luchegorsk
# Processing Record 13 of Set 5 | udachny
# Processing Record 14 of Set 5 | katsuren-haebaru
# Processing Record 15 of Set 5 | outjo
# Processing Record 16 of Set 5 | barcelos
# Processing Record 17 of Set 5 | ingeniero guillermo n. juarez
# Processing Record 18 of Set 5 | kavieng
# Processing Record 19 of Set 5 | port mathurin
# Processing Record 20 of Set 5 | west island
# Processing Record 21 of Set 5 | san patricio
# Processing Record 22 of Set 5 | lakatoro
# Processing Record 23 of Set 5 | tazovsky
# Processing Record 24 of Set 5 | broome
# Processing Record 25 of Set 5 | san andres
# Processing Record 26 of Set 5 | crane
# Processing Record 27 of Set 5 | iwon-up
# Processing Record 28 of Set 5 | petawawa
# Processing Record 29 of Set 5 | khandud
# Processing Record 30 of Set 5 | aripuana
# Processing Record 31 of Set 5 | goroka
# Processing Record 32 of Set 5 | marka
# Processing Record 33 of Set 5 | cable beach
# City not found. Skipping...
# Processing Record 34 of Set 5 | praia da vitoria
# Processing Record 35 of Set 5 | hamilton
# Processing Record 36 of Set 5 | vilyuysk
# Processing Record 37 of Set 5 | flying fish cove
# Processing Record 38 of Set 5 | adre
# Processing Record 39 of Set 5 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 40 of Set 5 | kudahuvadhoo
# Processing Record 41 of Set 5 | oranjemund
# Processing Record 42 of Set 5 | hadibu
# Processing Record 43 of Set 5 | pleasanton
# Processing Record 44 of Set 5 | mil'kovo
# Processing Record 45 of Set 5 | lebu
# Processing Record 46 of Set 5 | tarawa
# Processing Record 47 of Set 5 | college
# Processing Record 48 of Set 5 | remire-montjoly
# Processing Record 49 of Set 5 | guarapuava
# Processing Record 0 of Set 6 | yaring
# Processing Record 1 of Set 6 | dolbeau-mistassini
# Processing Record 2 of Set 6 | suai
# City not found. Skipping...
# Processing Record 3 of Set 6 | salekhard
# Processing Record 4 of Set 6 | ust-nera
# Processing Record 5 of Set 6 | coquimbo
# Processing Record 6 of Set 6 | berriane
# Processing Record 7 of Set 6 | page
# Processing Record 8 of Set 6 | taunggyi
# Processing Record 9 of Set 6 | nuuk
# Processing Record 10 of Set 6 | sosnogorsk
# Processing Record 11 of Set 6 | berezovyy
# Processing Record 12 of Set 6 | kogalym
# Processing Record 13 of Set 6 | torghay
# Processing Record 14 of Set 6 | kerch
# Processing Record 15 of Set 6 | soure
# Processing Record 16 of Set 6 | hobyo
# Processing Record 17 of Set 6 | alotau
# Processing Record 18 of Set 6 | labrador city
# Processing Record 19 of Set 6 | ararat
# Processing Record 20 of Set 6 | ekuvukeni
# Processing Record 21 of Set 6 | santiago de cao
# Processing Record 22 of Set 6 | broken hill
# Processing Record 23 of Set 6 | wuxi
# Processing Record 24 of Set 6 | ouellah
# City not found. Skipping...
# Processing Record 25 of Set 6 | nantucket
# Processing Record 26 of Set 6 | tosontsengel
# Processing Record 27 of Set 6 | boyolangu
# Processing Record 28 of Set 6 | coahuayana de hidalgo
# Processing Record 29 of Set 6 | corbu
# Processing Record 30 of Set 6 | nova sintra
# Processing Record 31 of Set 6 | aykhal
# Processing Record 32 of Set 6 | margate
# Processing Record 33 of Set 6 | hithadhoo
# Processing Record 34 of Set 6 | sanctuary point
# Processing Record 35 of Set 6 | afaahiti
# Processing Record 36 of Set 6 | vorgashor
# Processing Record 37 of Set 6 | shengli
# Processing Record 38 of Set 6 | san clemente del tuyu
# Processing Record 39 of Set 6 | ardakan
# Processing Record 40 of Set 6 | kiunga
# Processing Record 41 of Set 6 | handan
# Processing Record 42 of Set 6 | melfort
# Processing Record 43 of Set 6 | apolinario saravia
# Processing Record 44 of Set 6 | nova russas
# Processing Record 45 of Set 6 | bamyan
# Processing Record 46 of Set 6 | mount isa
# Processing Record 47 of Set 6 | hastings
# Processing Record 48 of Set 6 | chibougamau
# Processing Record 49 of Set 6 | chayan
# Processing Record 0 of Set 7 | kailua-kona
# Processing Record 1 of Set 7 | kalmunai
# Processing Record 2 of Set 7 | kaga bandoro
# Processing Record 3 of Set 7 | usogorsk
# Processing Record 4 of Set 7 | luau
# Processing Record 5 of Set 7 | akjoujt
# Processing Record 6 of Set 7 | bansi
# Processing Record 7 of Set 7 | hlusk
# Processing Record 8 of Set 7 | shingu
# Processing Record 9 of Set 7 | pasuquin
# Processing Record 10 of Set 7 | ponta delgada
# Processing Record 11 of Set 7 | port lincoln
# Processing Record 12 of Set 7 | ascencion de guarayos
# Processing Record 13 of Set 7 | sangin
# Processing Record 14 of Set 7 | sola
# Processing Record 15 of Set 7 | mocimboa
# Processing Record 16 of Set 7 | canutama
# Processing Record 17 of Set 7 | maintirano
# Processing Record 18 of Set 7 | bikenibeu village
# Processing Record 19 of Set 7 | ushachy
# Processing Record 20 of Set 7 | astorga
# Processing Record 21 of Set 7 | banda aceh
# Processing Record 22 of Set 7 | koppies
# Processing Record 23 of Set 7 | turochak
# Processing Record 24 of Set 7 | kwolla
# Processing Record 25 of Set 7 | hayma'
# City not found. Skipping...
# Processing Record 26 of Set 7 | new albany
# Processing Record 27 of Set 7 | turkestan
# Processing Record 28 of Set 7 | mogok
# Processing Record 29 of Set 7 | huarmey
# Processing Record 30 of Set 7 | bodaybo
# Processing Record 31 of Set 7 | swift current
# Processing Record 32 of Set 7 | tughyl
# Processing Record 33 of Set 7 | pisco
# Processing Record 34 of Set 7 | shakhtinsk
# Processing Record 35 of Set 7 | ha'il
# Processing Record 36 of Set 7 | darwin
# Processing Record 37 of Set 7 | whitehorse
# Processing Record 38 of Set 7 | moose jaw
# Processing Record 39 of Set 7 | palmer
# Processing Record 40 of Set 7 | kuala tungkal
# Processing Record 41 of Set 7 | cabedelo
# Processing Record 42 of Set 7 | salalah
# Processing Record 43 of Set 7 | mahina
# Processing Record 44 of Set 7 | loango
# Processing Record 45 of Set 7 | yima
# Processing Record 46 of Set 7 | mikuni
# Processing Record 47 of Set 7 | cill airne
# Processing Record 48 of Set 7 | lompoc
# Processing Record 49 of Set 7 | nhamunda
# Processing Record 0 of Set 8 | alesund
# Processing Record 1 of Set 8 | xilin hot
# Processing Record 2 of Set 8 | fort st. john
# Processing Record 3 of Set 8 | la passe
# Processing Record 4 of Set 8 | dudinka
# Processing Record 5 of Set 8 | pacific grove
# Processing Record 6 of Set 8 | macapa
# Processing Record 7 of Set 8 | palenque
# Processing Record 8 of Set 8 | richmond
# Processing Record 9 of Set 8 | puerto deseado
# Processing Record 10 of Set 8 | myitkyina
# Processing Record 11 of Set 8 | minusinsk
# Processing Record 12 of Set 8 | puerto escondido
# Processing Record 13 of Set 8 | bornos
# Processing Record 14 of Set 8 | dhuusamarreeb
# Processing Record 15 of Set 8 | praia
# Processing Record 16 of Set 8 | bamusso
# Processing Record 17 of Set 8 | novyy turtkul'
# Processing Record 18 of Set 8 | selfoss
# Processing Record 19 of Set 8 | olyokminsk
# Processing Record 20 of Set 8 | conde
# Processing Record 21 of Set 8 | uturoa
# Processing Record 22 of Set 8 | xining
# Processing Record 23 of Set 8 | ostersund
# Processing Record 24 of Set 8 | palmas de monte alto
# Processing Record 25 of Set 8 | sabang
# Processing Record 26 of Set 8 | onega
# Processing Record 27 of Set 8 | muisne
# Processing Record 28 of Set 8 | altai
# Processing Record 29 of Set 8 | tahe
# Processing Record 30 of Set 8 | jindabyne
# Processing Record 31 of Set 8 | lautoka
# Processing Record 32 of Set 8 | lorengau
# Processing Record 33 of Set 8 | deqen
# Processing Record 34 of Set 8 | barabai
# Processing Record 35 of Set 8 | viedma
# Processing Record 36 of Set 8 | changzhi
# Processing Record 37 of Set 8 | nyurba
# Processing Record 38 of Set 8 | thief river falls
# Processing Record 39 of Set 8 | naze
# Processing Record 40 of Set 8 | lospalos
# Processing Record 41 of Set 8 | middlesboro
# Processing Record 42 of Set 8 | hasaki
# Processing Record 43 of Set 8 | cornelio procopio
# Processing Record 44 of Set 8 | coxim
# Processing Record 45 of Set 8 | midvagur
# Processing Record 46 of Set 8 | kingscliff
# Processing Record 47 of Set 8 | tralee
# Processing Record 48 of Set 8 | zhangatas
# Processing Record 49 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 0 of Set 9 | fale old settlement
# Processing Record 1 of Set 9 | corn island
# Processing Record 2 of Set 9 | crucecita
# Processing Record 3 of Set 9 | sake
# Processing Record 4 of Set 9 | gunjur
# Processing Record 5 of Set 9 | mejit
# Processing Record 6 of Set 9 | les anglais
# Processing Record 7 of Set 9 | queenstown
# Processing Record 8 of Set 9 | zhaozhou
# Processing Record 9 of Set 9 | sidhi
# Processing Record 10 of Set 9 | fomboni
# Processing Record 11 of Set 9 | port alfred
# Processing Record 12 of Set 9 | tver
# Processing Record 13 of Set 9 | gwadar
# Processing Record 14 of Set 9 | buabidi
# City not found. Skipping...
# Processing Record 15 of Set 9 | sandnessjoen
# Processing Record 16 of Set 9 | jayuya
# Processing Record 17 of Set 9 | alice springs
# Processing Record 18 of Set 9 | sicuani
# Processing Record 19 of Set 9 | belel
# Processing Record 20 of Set 9 | moyamba
# Processing Record 21 of Set 9 | hammerfest
# Processing Record 22 of Set 9 | galesong
# Processing Record 23 of Set 9 | bereket
# Processing Record 24 of Set 9 | pagar alam
# Processing Record 25 of Set 9 | sao mateus
# Processing Record 26 of Set 9 | constitucion
# Processing Record 27 of Set 9 | ormara
# Processing Record 28 of Set 9 | pahrump
# Processing Record 29 of Set 9 | severodvinsk
# Processing Record 30 of Set 9 | popondetta
# Processing Record 31 of Set 9 | russkiy
# Processing Record 32 of Set 9 | veraval
# Processing Record 33 of Set 9 | zliten
# Processing Record 34 of Set 9 | lagonegro
# Processing Record 35 of Set 9 | guerrero negro
# Processing Record 36 of Set 9 | overland park
# Processing Record 37 of Set 9 | toliara
# Processing Record 38 of Set 9 | inhambane
# Processing Record 39 of Set 9 | regina
# Processing Record 40 of Set 9 | bocas del toro
# Processing Record 41 of Set 9 | ierapetra
# Processing Record 42 of Set 9 | west bay
# Processing Record 43 of Set 9 | east london
# Processing Record 44 of Set 9 | rauma
# Processing Record 45 of Set 9 | tamanrasset
# Processing Record 46 of Set 9 | stephenville
# Processing Record 47 of Set 9 | casino
# Processing Record 48 of Set 9 | miles city
# Processing Record 49 of Set 9 | belmonte
# Processing Record 0 of Set 10 | el granada
# Processing Record 1 of Set 10 | smithers
# Processing Record 2 of Set 10 | pumiao
# Processing Record 3 of Set 10 | machico
# Processing Record 4 of Set 10 | polyarnyy
# Processing Record 5 of Set 10 | new plymouth
# Processing Record 6 of Set 10 | prince rupert
# Processing Record 7 of Set 10 | nelson bay
# Processing Record 8 of Set 10 | tutoia
# Processing Record 9 of Set 10 | kayes
# Processing Record 10 of Set 10 | fort wellington
# Processing Record 11 of Set 10 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 12 of Set 10 | merizo village
# Processing Record 13 of Set 10 | nan
# Processing Record 14 of Set 10 | sorso
# Processing Record 15 of Set 10 | la ronge
# Processing Record 16 of Set 10 | khenchela
# Processing Record 17 of Set 10 | novyy urgal
# Processing Record 18 of Set 10 | novoanninskiy
# Processing Record 19 of Set 10 | gulu
# Processing Record 20 of Set 10 | robertsport
# Processing Record 21 of Set 10 | muzayri'
# City not found. Skipping...
# Processing Record 22 of Set 10 | hamza
# Processing Record 23 of Set 10 | qalat
# Processing Record 24 of Set 10 | varna
# Processing Record 25 of Set 10 | batumi
# Processing Record 26 of Set 10 | contamana
# Processing Record 27 of Set 10 | asheboro
# Processing Record 28 of Set 10 | khanty-mansiysk
# Processing Record 29 of Set 10 | mitchell
# Processing Record 30 of Set 10 | al kharijah
# Processing Record 31 of Set 10 | kill devil hills
# Processing Record 32 of Set 10 | gazojak
# Processing Record 33 of Set 10 | berdigestyakh
# Processing Record 34 of Set 10 | devinuwara
# City not found. Skipping...
# Processing Record 35 of Set 10 | hirara
# Processing Record 36 of Set 10 | porto novo
# Processing Record 37 of Set 10 | zalari
# Processing Record 38 of Set 10 | tsiombe
# Processing Record 39 of Set 10 | ixtapa
# Processing Record 40 of Set 10 | sur
# Processing Record 41 of Set 10 | cranbrook
# Processing Record 42 of Set 10 | luderitz
# Processing Record 43 of Set 10 | azadshahr
# Processing Record 44 of Set 10 | santa elena de uairen
# Processing Record 45 of Set 10 | orange walk
# Processing Record 46 of Set 10 | soyaux
# Processing Record 47 of Set 10 | vernon
# Processing Record 48 of Set 10 | woolgoolga
# Processing Record 49 of Set 10 | nova vicosa
# Processing Record 0 of Set 11 | belabo
# Processing Record 1 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 2 of Set 11 | arrifes
# Processing Record 3 of Set 11 | al fintas
# Processing Record 4 of Set 11 | shakiso
# Processing Record 5 of Set 11 | kamaishi
# Processing Record 6 of Set 11 | yeniseysk
# Processing Record 7 of Set 11 | saguenay
# Processing Record 8 of Set 11 | riviere-du-loup
# Processing Record 9 of Set 11 | monte mor
# Processing Record 10 of Set 11 | fonte boa
# Processing Record 11 of Set 11 | juneau
# Processing Record 12 of Set 11 | mugia
# Processing Record 13 of Set 11 | koidu
# Processing Record 14 of Set 11 | vila velha
# Processing Record 15 of Set 11 | bentiu
# Processing Record 16 of Set 11 | marsaskala
# City not found. Skipping...
# Processing Record 17 of Set 11 | moyale
# Processing Record 18 of Set 11 | litchfield
# Processing Record 19 of Set 11 | tazacorte
# Processing Record 20 of Set 11 | magistral'nyy
# Processing Record 21 of Set 11 | san bernardo del viento
# Processing Record 22 of Set 11 | burkburnett
# Processing Record 23 of Set 11 | itoman
# Processing Record 24 of Set 11 | ceelbuur
# Processing Record 25 of Set 11 | holualoa
# Processing Record 26 of Set 11 | santiago de cuba
# Processing Record 27 of Set 11 | brookings
# Processing Record 28 of Set 11 | weno
# Processing Record 29 of Set 11 | puerto san jose
# Processing Record 30 of Set 11 | plesetsk
# Processing Record 31 of Set 11 | tual
# Processing Record 32 of Set 11 | rongelap
# Processing Record 33 of Set 11 | carauari
# Processing Record 34 of Set 11 | kerikeri
# Processing Record 35 of Set 11 | namsos
# Processing Record 36 of Set 11 | choibalsan
# Processing Record 37 of Set 11 | kirkwall
# Processing Record 38 of Set 11 | zhanaozen
# Processing Record 39 of Set 11 | figueres
# Processing Record 40 of Set 11 | barra de santo antonio
# Processing Record 41 of Set 11 | urangan
# Processing Record 42 of Set 11 | aasiaat
# Processing Record 43 of Set 11 | kas
# Processing Record 44 of Set 11 | belalcazar
# Processing Record 45 of Set 11 | okha
# Processing Record 46 of Set 11 | ikwiriri
# Processing Record 47 of Set 11 | dschang
# Processing Record 48 of Set 11 | fauske
# Processing Record 49 of Set 11 | bardaskan
# City not found. Skipping...
# Processing Record 0 of Set 12 | promyshlennaya
# Processing Record 1 of Set 12 | madang
# Processing Record 2 of Set 12 | plettenberg bay
# Processing Record 3 of Set 12 | cromer
# Processing Record 4 of Set 12 | fuglafjordur
# Processing Record 5 of Set 12 | pokhara
# Processing Record 6 of Set 12 | tongchuanshi
# Processing Record 7 of Set 12 | sosnovka
# Processing Record 8 of Set 12 | nagqu
# Processing Record 9 of Set 12 | princeville
# Processing Record 10 of Set 12 | tomatlan
# Processing Record 11 of Set 12 | bahir dar
# Processing Record 12 of Set 12 | privas
# Processing Record 13 of Set 12 | yantarnyy
# Processing Record 14 of Set 12 | randfontein
# Processing Record 15 of Set 12 | dinga
# Processing Record 16 of Set 12 | malaya vishera
# Processing Record 17 of Set 12 | sarkand
# Processing Record 18 of Set 12 | bodo
# Processing Record 19 of Set 12 | bonny
# Processing Record 20 of Set 12 | kiruna
# Processing Record 21 of Set 12 | ust'-ilimsk
# Processing Record 22 of Set 12 | huanuco
# Processing Record 23 of Set 12 | gunnedah
# Processing Record 24 of Set 12 | zelenogorskiy
# Processing Record 25 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 26 of Set 12 | wenatchee
# Processing Record 27 of Set 12 | huruta
# Processing Record 28 of Set 12 | ust-tsilma
# Processing Record 29 of Set 12 | saint-pierre
# Processing Record 30 of Set 12 | macusani
# Processing Record 31 of Set 12 | korla
# Processing Record 32 of Set 12 | novodvinsk
# Processing Record 33 of Set 12 | castillos
# Processing Record 34 of Set 12 | monduli
# Processing Record 35 of Set 12 | saint-francois
# Processing Record 36 of Set 12 | selkirk
# Processing Record 37 of Set 12 | cooper's town
# Processing Record 38 of Set 12 | berrotaran
# Processing Record 39 of Set 12 | oak island
# Processing Record 40 of Set 12 | saint-paul
# Processing Record 41 of Set 12 | shima
# Processing Record 42 of Set 12 | maceio
# Processing Record 43 of Set 12 | palopo
# Processing Record 44 of Set 12 | zharkent
# Processing Record 45 of Set 12 | sarmiento
# Processing Record 46 of Set 12 | tidjikja
# Processing Record 47 of Set 12 | swan hill
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       adamstown -25.0660 -130.1015     21.02        74          43
# 1   cam pha mines  21.0167  107.3000     27.34        85          43
# 2    punta arenas -53.1500  -70.9167      2.06        75         100
# 3  margaret river -33.9500  115.0667      9.76        92           3
# 4       kavaratti  10.5669   72.6420     27.71        79         100
#
#    Wind Speed Country        Date
# 0        6.73      PN  1722731261
# 1        3.94      VN  1722731352
# 2        5.14      CL  1722731314
# 3        3.55      AU  1722731055
# 4        5.87      IN  1722731355

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             adamstown -25.0660 -130.1015     21.02        74          43
# 1         cam pha mines  21.0167  107.3000     27.34        85          43
# 2          punta arenas -53.1500  -70.9167      2.06        75         100
# 3        margaret river -33.9500  115.0667      9.76        92           3
# 4             kavaratti  10.5669   72.6420     27.71        79         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.73      PN  1722731261
# 1              3.94      VN  1722731352
# 2              5.14      CL  1722731314
# 3              3.55      AU  1722731055
# 4              5.87      IN  1722731355

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(x="Lat", y="Max Temp", kind="scatter", edgecolor='black', s=35)

# Incorporate the other graph properties
date = city_data_df["Date"].apply(lambda x: time.strftime("%Y-%m-%d", time.localtime(x))).to_list()[0]
plt.title(f"City Max Latitude vs. Temperature ({date})")
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(x="Lat", y="Humidity", kind="scatter", edgecolor='black', s=35)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({date})")
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(x="Lat", y="Cloudiness", kind="scatter", edgecolor='black', s=35)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(x="Lat", y="Wind Speed", kind="scatter", edgecolor='black', s=35)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_scatter(x, y, xlabel="x", ylabel="y"):
    (slope, intercept, rvalue, _, _) = linregress(x, y)
    regress_values = x * slope + intercept
    print(f"The r^2 value is {rvalue}")
    plt.scatter(x, y)
    plt.plot(x, regress_values, color="red")
    equation_text = f'y = {slope:.2f}x + {intercept:.1f}'
    plt.text(x=x.min(), y=y.max(), s=equation_text, fontsize=10, color='red', verticalalignment='top')
    plt.title(f"{xlabel} vs {ylabel}")
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        cam pha mines  21.0167  107.3000     27.34        85          43
# 4            kavaratti  10.5669   72.6420     27.71        79         100
# 5            chahuites  16.2833  -94.1833     28.82        80          66
# 6              lincoln  40.8000  -96.6670     34.38        37           0
# 8               newman  37.3138 -121.0208     41.13        14          16
#
#          Wind Speed Country        Date
# City_ID
# 1              3.94      VN  1722731352
# 4              5.87      IN  1722731355
# 5              1.68      MX  1722731357
# 6              2.06      US  1722731137
# 8              1.50      US  1722731360

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     21.02        74          43
# 2             punta arenas -53.1500  -70.9167      2.06        75         100
# 3           margaret river -33.9500  115.0667      9.76        92           3
# 7                 waitangi -43.9535 -176.5597      8.79        87          76
# 10       port-aux-francais -49.3500   70.2167      2.46        86          35
#
#          Wind Speed Country        Date
# City_ID
# 0              6.73      PN  1722731261
# 2              5.14      CL  1722731314
# 3              3.55      AU  1722731055
# 7              3.13      NZ  1722731225
# 10             8.58      TF  1722731236

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_scatter(x=northern_hemi_df["Lat"], y=northern_hemi_df["Max Temp"], xlabel="Latitude", ylabel="Max Temperature (C)")
# Out:
# The r^2 value is -0.5595764464778396

# %%
# Linear regression on Southern Hemisphere
plot_scatter(x=southern_hemi_df["Lat"], y=southern_hemi_df["Max Temp"], xlabel="Latitude", ylabel="Max Temperature (C)")
# Out:
# The r^2 value is 0.8026697458365207

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_scatter(x=northern_hemi_df["Lat"], y=northern_hemi_df["Humidity"], xlabel="Latitude", ylabel="Humidity (%)")
# Out:
# The r^2 value is -0.11565118317571847

# %%
# Southern Hemisphere
plot_scatter(x=southern_hemi_df["Lat"], y=southern_hemi_df["Humidity"], xlabel="Latitude", ylabel="Humidity (%)")
# Out:
# The r^2 value is 0.07258339122305602

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_scatter(x=northern_hemi_df["Lat"], y=northern_hemi_df["Cloudiness"], xlabel="City Latitude", ylabel="Cloudiness (%)")
# Out:
# The r^2 value is -0.08317228371862334

# %%
# Southern Hemisphere
plot_scatter(x=southern_hemi_df["Lat"], y=southern_hemi_df["Cloudiness"], xlabel="City Latitude", ylabel="Cloudiness (%)")
# Out:
# The r^2 value is -0.22256272350254727

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_scatter(x=northern_hemi_df["Lat"], y=northern_hemi_df["Wind Speed"], xlabel="City Latitude", ylabel="Wind Speed (m/s)")
# Out:
# The r^2 value is -0.009862881011026309

# %%
# Southern Hemisphere
plot_scatter(x=southern_hemi_df["Lat"], y=southern_hemi_df["Wind Speed"], xlabel="City Latitude", ylabel="Wind Speed (m/s)")
# Out:
# The r^2 value is -0.03706481549577091

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
